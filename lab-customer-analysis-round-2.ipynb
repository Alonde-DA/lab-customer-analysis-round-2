# %%
import pandas as pd
import numpy as np

# %%
file1 = pd.read_csv(r'C:\Users\a_del\OneDrive\Desktop\Ironhack-weeks\Week2\lab-customer-analysis-round-2\Copy of day3_file2_sep.txt', sep = '\t')
file2 =pd.read_csv(r'C:\Users\a_del\OneDrive\Desktop\Ironhack-weeks\Week2\lab-customer-analysis-round-2\Copy of day3_file1.csv')

# %%
file1
# Out:
#        Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877         NaN              6857.519928      NaN
#
#        Coverage Education Effective To Date EmploymentStatus Gender  ...  \
# ...

# %%
file2
# Out:
#       CONTROLN STATE GENDER      HV1  IC1    IC4  HVP1    IC5  POBC1  POBC2  \
# 0        44060    FL      M   AAA896  392  520.0     7  21975      6     16
# 1        96093    IL      M   537.00  365  473.0     0  19387      1     89
# 2        43333    FL      F   725.00  301  436.0     3  18837     11     17
# 3        21885    NC      M  AAA1095  401  413.0     7  14014      1     74
# 4       190108    FL      F   995.00  252  348.0     0  17991      5      6
# ...        ...   ...    ...      ...  ...    ...   ...    ...    ...    ...
# 1002    114721    OK    NaN     1040  472  656.0     0  26962      2     56
# 1003    149152    CA      M     4507  842  962.0    95  54642     17     50
# 1004       959    IA      F      586  349  465.0     1  15304      1     77
# 1005    179563    WA   male      842  420  494.0     2  12894     41     24
# 1006     41243    FL      F      556  246  330.0     0  10272      2     56
#
# ...

# %%
#Show the dataframe shape

# %%
file1.shape
# Out:
# (1015, 17)

# %%
#Standardize header names

# %%
data = pd.concat([file1,file2])

# %%
data.columns = data.columns.str.lower()

# %%
data = data.rename(columns={'controln':'ID',
                            'hv1':'median_home_val',
                            'ic1':'median_household_income'})

# %%
#Which columns are numerical #Which columns are categorical

# %%
data.dtypes
# Out:
# ID                           int64
# state                       object
# gender                      object
# median_home_val             object
# median_household_income      int64
# ic4                        float64
# hvp1                         int64
# ic5                         object
# pobc1                        int64
# pobc2                        int64
# ic2                        float64
# ic3                          int64
# avggift                    float64
# tcode                        int64
# dob                          int64
# domain                      object
# target_d                   float64
# dtype: object

# %%
#Check and deal with NaN values

# %%
data.isnull().values.any()
# Out:
# True

# %%
data=data.dropna(axis=0)

# %%
data
# Out:
#           ID state   gender median_home_val  median_household_income    ic4  \
# 0     190579    CA        M            3200                      310  343.0
# 1      42997    FL        F            1567                      392  409.0
# 2     132896    OR        F             953                      319  455.0
# 3     120189    TX        M             492                      244  301.0
# 4     138829    AZ  feamale             847                      185  308.0
# ...      ...   ...      ...             ...                      ...    ...
# 1001   41384    FL        F             556                      318  352.0
# 1003  149152    CA        M            4507                      842  962.0
# 1004     959    IA        F             586                      349  465.0
# 1005  179563    WA     male             842                      420  494.0
# 1006   41243    FL        F             556                      246  330.0
#
# ...

# %%
#Datetime format - Extract the months from the dataset and store in a separate column. Then filter the data to show only the information for the first quarter , ie. January, February and March. Hint: If data from March does not exist, consider only January and February

# %%
file3 = pd.read_csv(r'C:\Users\a_del\OneDrive\Desktop\Ironhack-weeks\Week2\lab-customer-analysis-round-2\Copy of day4_df_final_web_data_pt_1.csv')

# %%
file3
# Out:
#         Unnamed: 0  client_id            visitor_id  \
# 0                0    9988021  580560515_7732621733
# 1                1    9988021  580560515_7732621733
# 2                2    9988021  580560515_7732621733
# 3                3    9988021  580560515_7732621733
# 4                4    9988021  580560515_7732621733
# ...            ...        ...                   ...
# 204611      204611    9485108  14504433_98884916993
# 204612      204612    9485108  14504433_98884916993
# 204613      204613    9485108  14504433_98884916993
# 204614      204614    9485108  14504433_98884916993
# 204615      204615    9485108             14504433_
#
#                             visit_id process_step      date_time
# 0       781255054_21935453173_531117       step_3  4/17/17 15:27
# 1       781255054_21935453173_531117       step_2  4/17/17 15:26
# 2       781255054_21935453173_531117       step_3  4/17/17 15:19
# 3       781255054_21935453173_531117       step_2  4/17/17 15:19
# ...

# %%
file3['date_time']
# Out:
# 0         4/17/17 15:27
# 1         4/17/17 15:26
# 2         4/17/17 15:19
# 3         4/17/17 15:19
# 4         4/17/17 15:18
#               ...
# 204611     4/6/17 11:58
# 204612     4/6/17 11:56
# 204613     4/6/17 11:55
# 204614     4/6/17 11:54
# 204615              NaN
# Name: date_time, Length: 204616, dtype: object

# %%
file3['date_time'] = pd.to_datetime(file3['date_time']) # , errors='coerce'
file3['date_time']
# Out:
# 0        2017-04-17 15:27:00
# 1        2017-04-17 15:26:00
# 2        2017-04-17 15:19:00
# 3        2017-04-17 15:19:00
# 4        2017-04-17 15:18:00
#                  ...
# 204611   2017-04-06 11:58:00
# 204612   2017-04-06 11:56:00
# 204613   2017-04-06 11:55:00
# 204614   2017-04-06 11:54:00
# 204615                   NaT
# Name: date_time, Length: 204616, dtype: datetime64[ns]

# %%
# Out:
#         Unnamed: 0  client_id            visitor_id  \
# 0                0    9988021  580560515_7732621733
# 1                1    9988021  580560515_7732621733
# 2                2    9988021  580560515_7732621733
# 3                3    9988021  580560515_7732621733
# 4                4    9988021  580560515_7732621733
# ...            ...        ...                   ...
# 204611      204611    9485108  14504433_98884916993
# 204612      204612    9485108  14504433_98884916993
# 204613      204613    9485108  14504433_98884916993
# 204614      204614    9485108  14504433_98884916993
# 204615      204615    9485108             14504433_
#
#                             visit_id process_step           date_time
# 0       781255054_21935453173_531117       step_3 2017-04-17 15:27:00
# 1       781255054_21935453173_531117       step_2 2017-04-17 15:26:00
# 2       781255054_21935453173_531117       step_3 2017-04-17 15:19:00
# ...

# %%
file3['date_time'].dt.month
# Out:
# 0         4.0
# 1         4.0
# 2         4.0
# 3         4.0
# 4         4.0
#          ...
# 204611    4.0
# 204612    4.0
# 204613    4.0
# 204614    4.0
# 204615    NaN
# Name: date_time, Length: 204616, dtype: float64

# %%
file3['new_column'] = file3['date_time'].dt.month

# %%
file3
# Out:
#         Unnamed: 0  client_id            visitor_id  \
# 0                0    9988021  580560515_7732621733
# 1                1    9988021  580560515_7732621733
# 2                2    9988021  580560515_7732621733
# 3                3    9988021  580560515_7732621733
# 4                4    9988021  580560515_7732621733
# ...            ...        ...                   ...
# 204611      204611    9485108  14504433_98884916993
# 204612      204612    9485108  14504433_98884916993
# 204613      204613    9485108  14504433_98884916993
# 204614      204614    9485108  14504433_98884916993
# 204615      204615    9485108             14504433_
#
#                             visit_id process_step           date_time  \
# 0       781255054_21935453173_531117       step_3 2017-04-17 15:27:00
# 1       781255054_21935453173_531117       step_2 2017-04-17 15:26:00
# 2       781255054_21935453173_531117       step_3 2017-04-17 15:19:00
# ...

# %%
file3 = file3[file3['date_time'].dt.quarter == 1]

# %%
file3
# Out:
#         Unnamed: 0  client_id             visitor_id  \
# 118            118    2354414  146216735_55070797578
# 119            119    2354414  146216735_55070797578
# 120            120    2354414  146216735_55070797578
# 121            121    2354414  146216735_55070797578
# 122            122    2354414  146216735_55070797578
# ...            ...        ...                    ...
# 204583      204583    3681208  422155984_25066776375
# 204597      204597    5589543  293700162_16561696580
# 204598      204598    5589543  293700162_16561696580
# 204599      204599    5589543  293700162_16561696580
# 204600      204600    5589543  293700162_16561696580
#
#                             visit_id process_step           date_time  \
# 118      71074670_81016907082_663028      confirm 2017-03-29 12:26:00
# 119      71074670_81016907082_663028       step_3 2017-03-29 12:25:00
# 120      71074670_81016907082_663028       step_2 2017-03-29 12:25:00
# ...

# %%
#BONUS: Put all the previously mentioned data transformations into a function
